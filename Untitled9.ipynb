# %% [markdown]
# <a href="https://colab.research.google.com/github/TANYA-CHAN/NLP_SummerProject_Drafts/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
path1 = "/content/drive/My Drive/Colab Notebooks/lyrics1.csv"
df = pd.read_csv(path1)

# %%
import pandas as pd
import numpy as np

# %%
df['ranker_genre'] = np.where(
    (df['ranker_genre'] == 'screamo')|
    (df['ranker_genre'] == 'punk rock')|
    (df['ranker_genre'] == 'heavy metal'), 
    'alt rock', 
    df['ranker_genre']
)

# %%
group = ['song', 'year', 'album', 'genre', 'artist', 'ranker_genre']
lyrics_by_song = df.sort_values(group)\
        .groupby(group).lyric\
        .apply(' '.join)\
        .apply(lambda x: x.lower())\
        .reset_index(name='lyric')

# %%
lyrics_by_song["lyric"] = lyrics_by_song['lyric'].str.replace(r'[^\w\s]','')

# %%
from sklearn.utils import shuffle
from nltk.corpus import stopwords

# %%
genres = ['Country','alt rock', 'Hip Hop','pop']
LYRIC_LEN = 400
N = 10000
RANDOM_SEED = 200

# %%
train_df = pd.DataFrame()

# %%
test_df = pd.DataFrame()

# %%
for genre in genres:
  subset = lyrics_by_song[
      (lyrics_by_song.ranker_genre==genre)& 
        (lyrics_by_song.lyric.str.len()>=LYRIC_LEN)]
  train_set = subset.sample(n=N, random_state=RANDOM_SEED)
  test_set = subset.drop(train_set.index)
  train_df = train_df.append(train_set)
  test_df = test_df.append(test_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e81e7c58562f> in <module>()
#       5       (lyrics_by_song.ranker_genre==genre)&
#       6         (lyrics_by_song.lyric.str.len()>=LYRIC_LEN)]
# ----> 7   train_set = subset.sample(n=N, random_state=RANDOM_SEED)
#       8   test_set = subset.drop(train_set.index)
#       9   train_df = train_df.append(train_set)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5059             )
#    5060
# -> 5061         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5062         return self.take(locs, axis=axis)
#    5063
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
train_df = shuffle(train_df)
test_df = shuffle(test_df)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
text_clf = Pipeline(
    [('vect', CountVectorizer()),
     ('clf', MultinomialNB(alpha=0.1))])

# %%
text_clf.fit(train_df.lyric, train_df.ranker_genre)
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('clf',
#                  MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
predicted = text_clf.predict(test_df.lyric)
np.mean(predicted == test_df.ranker_genre)
# Out:
# 0.8089145687164672

# %%
from sklearn.metrics import confusion_matrix

# %%
mat = confusion_matrix(test_df.ranker_genre, predicted)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.heatmap(
    mat.T, square=True, annot=True, fmt='d', cbar=False,
    xticklabels=genres,
    yticklabels=genres
)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
precision, recall, fscore, support = precision_recall_fscore_support(test_df.ranker_genre, predicted)

# %%
for n,genre in enumerate(genres):
  genre = genre.upper()
  print(genre+'_precision: {}'.format(precision[n]))
  print(genre+'_recall: {}'.format(recall[n]))
  print(genre+'_fscore: {}'.format(fscore[n]))
  print(genre+'_support: {}'.format(support[n]))
  print()
# Out:
# COUNTRY_precision: 0.9443215572268218
# COUNTRY_recall: 0.8293278570239219
# COUNTRY_fscore: 0.8830969267139479
# COUNTRY_support: 18017
#
# ALT ROCK_precision: 0.6420274551214361
# ALT ROCK_recall: 0.9346656418139893
# ALT ROCK_fscore: 0.761189358372457
# ALT ROCK_support: 1301
#
# HIP HOP_precision: 0.8804294777940459
# HIP HOP_recall: 0.7556020942408377
# HIP HOP_fscore: 0.8132536909726137
# HIP HOP_support: 9550
#
# POP_precision: 0.046158710085362
# POP_recall: 0.7019230769230769
# POP_fscore: 0.0866211806585583
# POP_support: 208

# %%
text_clf.predict(
    [
        "i stand for the red white and blue",
        "flow so smooth they say i rap in cursive",
        "skateboard heres our ride",
        "take my heart and carve it out",
        "there is no end to the madness",
        "sitting on my front porch drinking sweet tea",
        "i believe whatever else you do",
        "sitting on my front porch sippin on cognac",
        "dog died and my pick up truck wont start",
        "im invisible and the drugs wont help",
        "lalala lalalala",
        "i hope you choke in your sleep thinking of me",
        "i wonder what genre a song about data science and naive bayes and hyper parameters and maybe a little scatter plots would be"
    ]
)
# Out:
# array(['Country', 'Hip Hop', 'pop', 'alt rock', 'alt rock', 'Country',
#        'pop', 'Hip Hop', 'Hip Hop', 'alt rock', 'pop', 'alt rock',
#        'Hip Hop'], dtype='<U8')

# %%
data = train_df.append(test_df) 
predicts = text_clf.predict_proba(data.lyric)

# %%
data['Country'], data['Hip_Hop'], data['Alt_Rock'], data['Pop']= ['','','','']
for n,row in enumerate(data.itertuples()):
  data.loc[row.Index, 'Country'] = predicts[n][0]
  data.loc[row.Index, 'Hip_Hop'] = predicts[n][1]
  data.loc[row.Index, 'Alt_Rock'] = predicts[n][2]
  data.loc[row.Index, 'Pop'] = predicts[n][3]

# %% [markdown]
# TOP HIP HOP SONGS

# %%
columns_of_interest = [
    'artist', 'song', 'album', 
    'ranker_genre', 'Hip_Hop', 
    'Alt_Rock', 'Country','Pop'
]

# %%
columns_of_interest = ['artist', 'song', 'album', 'ranker_genre', 'Hip_Hop', 'Alt_Rock', 'Country','Pop']
data[columns_of_interest].sort_values(['Hip_Hop'], ascending=False).head(10)
# Out:
#                   artist  ...           Pop
# 47256         Method_Man  ...  2.86866e-181
# 41918                DMX  ...  2.38641e-243
# 51392         Gang_Starr  ...             0
# 34707            Mos_Def  ...  1.85112e-124
# 45479            Raekwon  ...  1.13025e-145
# 54722           Warren_G  ...  2.41696e-150
# 8294             Pusha_T  ...  2.70473e-106
# 35144   Childish_Gambino  ...  1.61904e-179
# 47052        Wiz_Khalifa  ...     1.912e-96
# 2399   Chance_The_Rapper  ...   1.00816e-24
#
# [10 rows x 8 columns]

# %%
data[columns_of_interest]\
    .sort_values(['Hip_Hop', 'Alt_Rock', 'Country'], ascending=[1, 0, 1])\
    .head(20)
# Out:
#                                 artist  ... Pop
# 15588                             NOFX  ...   0
# 28976  We Butter the Bread With Butter  ...   0
# 2617   We Butter the Bread With Butter  ...   0
# 15588                             NOFX  ...   0
# 33317  We Butter the Bread With Butter  ...   0
# 11053  We Butter the Bread With Butter  ...   0
# 33318  We Butter the Bread With Butter  ...   0
# 13618  We Butter the Bread With Butter  ...   0
# 13618  We Butter the Bread With Butter  ...   0
# 46514                   Modern Talking  ...   1
# 46514                   Modern Talking  ...   1
# 32521                           Hanson  ...   1
# 32521                           Hanson  ...   1
# 32523                           Hanson  ...   1
# 32521                           Hanson  ...   1
# 32523                           Hanson  ...   1
# 32520                           Hanson  ...   1
# 32522                           Hanson  ...   1
# 32523                           Hanson  ...   1
# 32521                           Hanson  ...   1
#
# [20 rows x 8 columns]

# %%
data[columns_of_interest]\
    .sort_values(['Hip_Hop', 'Alt_Rock', 'Country'], ascending=[1, 1, 0])\
    .head(20)
# Out:
#                        artist  ... Pop
# 34530  Nitty Gritty Dirt Band  ...   0
# 34530  Nitty Gritty Dirt Band  ...   0
# 36796         Backstreet Boys  ...   1
# 51534                    Aqua  ...   1
# 55524      Christina Aguilera  ...   1
# 36796         Backstreet Boys  ...   1
# 10398      Christina Aguilera  ...   1
# 51534                    Aqua  ...   1
# 56074      Christina Aguilera  ...   1
# 51534                    Aqua  ...   1
# 38774           Justin Bieber  ...   1
# 38774           Justin Bieber  ...   1
# 38774           Justin Bieber  ...   1
# 16229      Christina Aguilera  ...   1
# 16229      Christina Aguilera  ...   1
# 38774           Justin Bieber  ...   1
# 51534                    Aqua  ...   1
# 36796         Backstreet Boys  ...   1
# 56073      Christina Aguilera  ...   1
# 36796         Backstreet Boys  ...   1
#
# [20 rows x 8 columns]

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest]\
    .sort_values(['Alt_Rock', 'Hip_Hop'], ascending=[0, 1])\
    .head(20)
# Out:
#                    artist  ...           Pop
# 55514  Immortal_Technique  ...  3.15132e-276
# 4801          Lupe_Fiasco  ...   1.14441e-35
# 56237            Scarface  ...   2.05735e-39
# 56237            Scarface  ...   2.05735e-39
# 41007                 DMX  ...   1.09409e-55
# 19309         Lupe_Fiasco  ...   3.30361e-48
# 19309         Lupe_Fiasco  ...   3.30361e-48
# 4951          Lupe_Fiasco  ...   3.68398e-20
# 4959               Eminem  ...   4.37862e-73
# 4959               Eminem  ...   4.37862e-73
# 30055         Lupe_Fiasco  ...   1.02706e-58
# 19070              Hopsin  ...   2.55991e-48
# 19070              Hopsin  ...   2.55991e-48
# 19070              Hopsin  ...   2.55991e-48
# 19070              Hopsin  ...   2.55991e-48
# 51774  Immortal_Technique  ...  4.58338e-251
# 8244                B.o.B  ...   2.70755e-23
# 38372  Immortal_Technique  ...  2.06789e-267
# 38372  Immortal_Technique  ...  2.06789e-267
# 8958                B.o.B  ...   9.65814e-43
#
# [20 rows x 8 columns]

# %%
data[data.ranker_genre=='Hip Hop'][columns_of_interest]\
    .sort_values(['Country'], ascending=[0])\
    .head(20)
# Out:
#           artist                   song  ... Country          Pop
# 3132         DMX                  Angel  ...       1   7.6585e-19
# 49282        DMX              Thank You  ...       1  6.00978e-36
# 27695        DMX         Jesus Loves Me  ...       1  2.18987e-37
# 27695        DMX         Jesus Loves Me  ...       1  2.18987e-37
# 3133         DMX                  Angel  ...       1   7.6585e-19
# 27695        DMX         Jesus Loves Me  ...       1  2.18987e-37
# 32231      B.o.B      Lovelier Than You  ...       1  1.84977e-27
# 49159   Yelawolf         Tennessee Love  ...       1  4.65422e-44
# 30436  Lil_Wayne             Lisa Marie  ...       1  3.74499e-78
# 32231      B.o.B      Lovelier Than You  ...       1  1.84977e-27
# 1185         DMX  A Minute For Your Son  ...       1  1.77216e-30
# 49282        DMX              Thank You  ...       1  6.00978e-36
# 32231      B.o.B      Lovelier Than You  ...       1  1.84977e-27
# 18172       T.I.             Hallelujah  ...       1  1.50624e-66
# 45925   Scarface                Someday  ...       1  1.42043e-41
# 1185         DMX  A Minute For Your Son  ...       1  1.77216e-30
# 27695        DMX         Jesus Loves Me  ...       1  2.18987e-37
# 49158   Yelawolf         Tennessee Love  ...       1  4.65422e-44
# 28220        DMC           Just Like Me  ...       1  1.25604e-75
# 32231      B.o.B      Lovelier Than You  ...       1  1.84977e-27
#
# [20 rows x 8 columns]

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv('lyrics1.csv')

# %%
comment_words = '' 
stopwords = set(STOPWORDS)

# %%
for genre in genres:
  if([lyrics_by_song==genre]):
    for val in df.lyric:
      val = str(val)
      tokens = val.split()
      for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
      comment_words += " ".join(tokens)+" "
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
